# %% [markdown]
# __Introduction to GeoPandas__
#
# https://geopandas.org/en/stable/getting_started/introduction.html

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !pip install geopandas

# %%
import geopandas as gpd

# %% [markdown]
# # модельные датасеты

# %%
# !pip3 install geodatasets

# %%
import geodatasets as gds

# %%
gdf = gpd.read_file( gds.get_path('nybb') )
# Out:
# Downloading file 'nybb_16a.zip' from 'https://www.nyc.gov/assets/planning/download/zip/data-maps/open-data/nybb_16a.zip' to '/home/mechanoid/.cache/geodatasets'.
# Extracting 'nybb_16a/nybb.shp' from '/home/mechanoid/.cache/geodatasets/nybb_16a.zip' to '/home/mechanoid/.cache/geodatasets/nybb_16a.zip.unzip'
# Extracting 'nybb_16a/nybb.shx' from '/home/mechanoid/.cache/geodatasets/nybb_16a.zip' to '/home/mechanoid/.cache/geodatasets/nybb_16a.zip.unzip'
# Extracting 'nybb_16a/nybb.dbf' from '/home/mechanoid/.cache/geodatasets/nybb_16a.zip' to '/home/mechanoid/.cache/geodatasets/nybb_16a.zip.unzip'
# Extracting 'nybb_16a/nybb.prj' from '/home/mechanoid/.cache/geodatasets/nybb_16a.zip' to '/home/mechanoid/.cache/geodatasets/nybb_16a.zip.unzip'

# %%
display(gdf)
# Out:
#    BoroCode       BoroName     Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330470.010332  1.623820e+09
# 1         4         Queens  896344.047763  3.045213e+09
# 2         3       Brooklyn  741080.523166  1.937479e+09
# 3         1      Manhattan  359299.096471  6.364715e+08
# 4         2          Bronx  464392.991824  1.186925e+09
#
#                                             geometry
# 0  MULTIPOLYGON (((970217.022 145643.332, 970227....
# 1  MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 2  MULTIPOLYGON (((1021176.479 151374.797, 102100...
# 3  MULTIPOLYGON (((981219.056 188655.316, 980940....
# 4  MULTIPOLYGON (((1012821.806 229228.265, 101278...

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
# gdf.to_file('nybb.geojson', driver="GeoJSON")

# %% [markdown]
# # меряем площадь областей

# %%
gdf = gdf.set_index("BoroName")
gdf["area"] = gdf.area
display(gdf[["area"]])
# Out:
#                        area
# BoroName
# Staten Island  1.623822e+09
# Queens         3.045214e+09
# Brooklyn       1.937478e+09
# Manhattan      6.364712e+08
# Bronx          1.186926e+09

# %% [markdown]
# # границы областей

# %%
gdf['boundary'] = gdf.boundary
display(gdf[['boundary']])

gdf['boundary'].plot()
# Out:
#                                                         boundary
# BoroName
# Staten Island  MULTILINESTRING ((970217.022 145643.332, 97022...
# Queens         MULTILINESTRING ((1029606.077 156073.814, 1029...
# Brooklyn       MULTILINESTRING ((1021176.479 151374.797, 1021...
# Manhattan      MULTILINESTRING ((981219.056 188655.316, 98094...
# Bronx          MULTILINESTRING ((1012821.806 229228.265, 1012...
# <Axes: >

# %% [markdown]
# # центры областей

# %%
gdf['centroid'] = gdf.centroid
display( gdf[['centroid']] )
gdf['centroid'].plot()
# Out:
#                                      centroid
# BoroName
# Staten Island    POINT (941639.45 150931.991)
# Queens         POINT (1034578.078 197116.604)
# Brooklyn        POINT (998769.115 174169.761)
# Manhattan       POINT (993336.965 222451.437)
# Bronx            POINT (1021174.79 249937.98)
# <Axes: >

# %% [markdown]
# # оценка расстояния

# %%
first_point = gdf['centroid'].iloc[0]
gdf['distance'] = gdf['centroid'].distance(first_point)
display( gdf[['distance']] )
display( gdf['distance'].mean() ) # среднее расстояние
# Out:
#                     distance
# BoroName
# Staten Island       0.000000
# Queens         103781.535276
# Brooklyn        61674.893421
# Manhattan       88247.742789
# Bronx          126996.283623
# np.float64(76140.09102166798)

# %% [markdown]
# # рисуем карты

# %%
gdf.sample(3)
# Out:
#                BoroCode     Shape_Leng    Shape_Area  \
# BoroName
# Brooklyn              3  741080.523166  1.937479e+09
# Staten Island         5  330470.010332  1.623820e+09
# Queens                4  896344.047763  3.045213e+09
#
#                                                         geometry  \
# BoroName
# Brooklyn       MULTIPOLYGON (((1021176.479 151374.797, 102100...
# Staten Island  MULTIPOLYGON (((970217.022 145643.332, 970227....
# Queens         MULTIPOLYGON (((1029606.077 156073.814, 102957...
#
#                        area  \
# BoroName
# Brooklyn       1.937478e+09
# Staten Island  1.623822e+09
# Queens         3.045214e+09
#
#                                                         boundary  \
# BoroName
# Brooklyn       MULTILINESTRING ((1021176.479 151374.797, 1021...
# Staten Island  MULTILINESTRING ((970217.022 145643.332, 97022...
# Queens         MULTILINESTRING ((1029606.077 156073.814, 1029...
#
#                                      centroid       distance
# BoroName
# Brooklyn        POINT (998769.115 174169.761)   61674.893421
# Staten Island    POINT (941639.45 150931.991)       0.000000
# Queens         POINT (1034578.078 197116.604)  103781.535276

# %%
# визуализация оценки площади областей
gdf.plot('area', legend=True, figsize=(14,9))
# Out:
# <Axes: >

# %%
# !pip install folium matplotlib mapclassify

# %%
# визуализация оценки площади областей c наложением на карту
gdf.explore('area', legend=False)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_186790d6e6a909292b52689f36839c39 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_186790d6e6a909292b52689f36839c39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_186790d6e6a909292b52689f36839c39 = L.map(
#                 &quot;map_186790d6e6a909292b52689f36839c39&quot;,
#                 {
#                     center: [40.70582408558539, -73.97780021351167],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_186790d6e6a909292b52689f36839c39);
#
#
#
#
#
#             var tile_layer_c71b62ab8039533401ec17350d4de5eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c71b62ab8039533401ec17350d4de5eb.addTo(map_186790d6e6a909292b52689f36839c39);
#
#
#             map_186790d6e6a909292b52689f36839c39.fitBounds(
#                 [[40.49611539517052, -74.25559136315213], [40.915532776000255, -73.7000090638712]],
#                 {}
#             );
#
#
#         function geo_json_ce2199605b11cebdb4a429f38dbd7c1f_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#297a8e&quot;, &quot;fillColor&quot;: &quot;#297a8e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#fde725&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#1f9a8a&quot;, &quot;fillColor&quot;: &quot;#1f9a8a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#3e4c8a&quot;, &quot;fillColor&quot;: &quot;#3e4c8a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_ce2199605b11cebdb4a429f38dbd7c1f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_ce2199605b11cebdb4a429f38dbd7c1f_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_ce2199605b11cebdb4a429f38dbd7c1f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_ce2199605b11cebdb4a429f38dbd7c1f_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_ce2199605b11cebdb4a429f38dbd7c1f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_ce2199605b11cebdb4a429f38dbd7c1f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_ce2199605b11cebdb4a429f38dbd7c1f = L.geoJson(null, {
#                 onEachFeature: geo_json_ce2199605b11cebdb4a42

# %%
gdf = gdf.set_geometry("centroid") # Switching the active geometry 
gdf.plot("area", legend=True)
# Out:
# <Axes: >

# %%
# рисование с наложением данных 
ax = gdf["geometry"].plot()
gdf["centroid"].plot(ax=ax, color="black")
# Out:
# <Axes: >

# %%
gdf = gdf.set_geometry("geometry") # set the active geometry back to the original

# %% [markdown]
# # выпуклая оболочка

# %%
gdf["convex_hull"] = gdf.convex_hull
# saving the first plot as an axis and setting alpha (transparency) to 0.5
ax = gdf["convex_hull"].plot(alpha=.5,figsize=(14,9))  
# passing the first plot and setting linewitdth to 0.5
gdf["boundary"].plot(ax=ax, color="white", linewidth=.5,figsize=(14,9))
# Out:
# <Axes: >

# %% [markdown]
# # увеличение областей (буферные зоны на границах)

# %%
# buffering the active geometry by 10 000 feet (geometry is already in feet)
gdf["buffered"] = gdf.buffer(10_000)

# buffering the centroid geometry by 10 000 feet (geometry is already in feet)
gdf["buffered_centroid"] = gdf["centroid"].buffer(10_000)

# saving the first plot as an axis and setting alpha (transparency) to 0.5
ax = gdf["buffered"].plot(alpha=.5,figsize=(14,9)) 

# passing the first plot as an axis to the second
gdf["buffered_centroid"].plot(ax=ax, color="red", alpha=.5,figsize=(14,9))  

# passing the first plot and setting linewitdth to 0.5
gdf["boundary"].plot(ax=ax, color="white", linewidth=.5,figsize=(14,9))
# Out:
# <Axes: >

# %% [markdown]
# # пересечение областей с учётом буферных зон

# %%
brooklyn = gdf.loc["Brooklyn", "geometry"]
brooklyn
# Out:
# <MULTIPOLYGON (((1021176.479 151374.797, 1021002.862 151329.108, 1020874.933...>

# %%
type(brooklyn)
# Out:
# shapely.geometry.multipolygon.MultiPolygon

# %%
gdf["buffered"].intersects(brooklyn)
# Out:
# BoroName
# Staten Island     True
# Queens            True
# Brooklyn          True
# Manhattan         True
# Bronx            False
# dtype: bool

# %% [markdown]
# # оценка попадания точки в область с учётом буферных зон

# %%
gdf["within"] = gdf["buffered_centroid"].within(gdf)
gdf["within"]
# Out:
# BoroName
# Staten Island     True
# Queens            True
# Brooklyn         False
# Manhattan        False
# Bronx            False
# Name: within, dtype: bool

# %%
gdf = gdf.set_geometry("buffered_centroid")

# using categorical plot and setting the position of the legend
ax = gdf.plot("within", legend=True, categorical=True,
              legend_kwds={'loc': "upper left"},figsize=(14,9))  

# passing the first plot and setting linewitdth to 0.5
gdf["boundary"].plot(ax=ax, color="black", linewidth=.5,figsize=(14,9))
# Out:
# <Axes: >

# %% [markdown]
# # преобразования систем координат

# %%
gdf.crs # Coordinate Reference System (CRS)
# Out:
# <Projected CRS: EPSG:2263>
# Name: NAD83 / New York Long Island (ftUS)
# Axis Info [cartesian]:
# - X[east]: Easting (US survey foot)
# - Y[north]: Northing (US survey foot)
# Area of Use:
# - name: United States (USA) - New York - counties of Bronx; Kings; Nassau; New York; Queens; Richmond; Suffolk.
# - bounds: (-74.26, 40.47, -71.8, 41.3)
# Coordinate Operation:
# - name: SPCS83 New York Long Island zone (US survey foot)
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
gdf = gdf.set_geometry("geometry")
boroughs_4326 = gdf.to_crs("EPSG:4326")
boroughs_4326.plot()
# Out:
# <Axes: >

# %%
boroughs_4326.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ---

# %%
# !pip3 install watermark
# Python package versions used
# %load_ext watermark
# %watermark --python
# %watermark --iversions
#
# Out:
# Python implementation: CPython
# Python version       : 3.13.5
# IPython version      : 8.32.0
#
# shapely    : 2.0.7
# geopandas  : 1.1.1
# geodatasets: 2024.8.0
